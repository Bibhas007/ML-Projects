# %% [markdown]
# # Diabetes Predictions

# %%
from sklearn.datasets import load_diabetes
import pandas as pd

# %%
dataset = load_diabetes()

# %%
dataset
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#         259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#         128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#         150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#         200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#          42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#          83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#         104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#         173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#         107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
#          60., 174., 259., 178., 128.,  96., 126., 288.,  88., 292.,  71.,
#         197., 186.,  25.,  84.,  96., 195.,  53., 217., 172., 131., 214.,
#          59.,  70., 220., 268., 152.,  47.,  74., 295., 101., 151., 127.,
#         237., 225.,  81., 151., 107.,  64., 138., 185., 265., 101., 137.,
#         143., 141.,  79., 292., 178.,  91., 116.,  86., 122.,  72., 129.,
#         142.,  90., 158.,  39., 196., 222., 277.,  99., 196., 202., 155.,
#          77., 191.,  70.,  73.,  49.,  65., 263., 248., 296., 214., 185.,
#          78.,  93., 252., 150.,  77., 208.,  77., 108., 160.,  53., 220.,
#         154., 259.,  90., 246., 124.,  67.,  72., 257., 262., 275., 177.,
#          71.,  47., 187., 125.,  78.,  51., 258., 215., 303., 243.,  91.,
#         150., 310., 153., 346.,  63.,  89.,  50.,  39., 103., 308., 116.,
#         145.,  74.,  45., 115., 264.,  87., 202., 127., 182., 241.,  66.,
#          94., 283.,  64., 102., 200., 265.,  94., 230., 181., 156., 233.,
#          60., 219.,  80.,  68., 332., 248.,  84., 200.,  55.,  85.,  89.,
#          31., 129.,  83., 275.,  65., 198., 236., 253., 124.,  44., 172.,
#         114., 142., 109., 180., 144., 163., 147.,  97., 220., 190., 109.,
#         191., 122., 230., 242., 248., 249., 192., 131., 237.,  78., 135.,
#         244., 199., 270., 164.,  72.,  96., 306.,  91., 214.,  95., 216.,
#         263., 178., 113., 200., 139., 139.,  88., 148.,  88., 243.,  71.,
#          77., 109., 272.,  60.,  54., 221.,  90., 311., 281., 182., 321.,
#          58., 262., 206., 233., 242., 123., 167.,  63., 197.,  71., 168.,
#         140., 217., 121., 235., 245.,  40.,  52., 104., 132.,  88.,  69.,
#         219.,  72., 201., 110.,  51., 277.,  63., 118.,  69., 273., 258.,
#          43., 198., 242., 232., 175.,  93., 168., 275., 293., 281.,  72.,
#         140., 189., 181., 209., 136., 261., 113., 131., 174., 257.,  55.,
#          84.,  42., 146., 212., 233.,  91., 111., 152., 120.,  67., 310.,
#          94., 183.,  66., 173.,  72.,  49.,  64.,  48., 178., 104., 132.,
#         220.,  57.]),
#  'frame': None,
#  'DESCR': '.. _diabetes_dataset:\n\nDiabetes dataset\n----------------\n\nTen baseline variables, age, sex, body mass index, average blood\npressure, and six blood serum measurements were obtained for each of n =\n442 diabetes patients, as well as the response of interest, a\nquantitative measure of disease progression one year after baseline.\n\n**Data Set Characteristics:**\n\n  :Number of Instances: 442\n\n  :Number of Attributes: First 10 columns are numeric predictive values\n\n  :Target: Column 11 is a quantitative measure of disease progression one year after baseline\n\n  :Attribute Information:\n      - age     age in years\n      - sex\n      - bmi     body mass index\n      - bp      average blood pressure\n      - s1      tc, total serum cholesterol\n      - s2      ldl, low-density lipoproteins\n      - s3      hdl, high-density lipoproteins\n      - s4      tch, total cholesterol / HDL\n      - s5      ltg, possibly log of serum triglycerides level\n      - s6      glu, blood sugar level\n\nNote: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).\n\nSource URL:\nhttps://www4.stat.ncsu.edu/~boos/var.select/diabetes.html\n\nFor more information see:\nBradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.\n(https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)\n',
#  'feature_names': ['age',
#   'sex',
#   'bmi',
#   'bp',
#   's1',
#   's2',
#   's3',
#   's4',
#   's5',
#   's6'],
#  'data_filename': 'diabetes_data_raw.csv.gz',
#  'target_filename': 'diabetes_target.csv.gz',
#  'data_module': 'sklearn.datasets.data'}

# %%
dataset['data']
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
dataset['DESCR']
# Out:
# '.. _diabetes_dataset:\n\nDiabetes dataset\n----------------\n\nTen baseline variables, age, sex, body mass index, average blood\npressure, and six blood serum measurements were obtained for each of n =\n442 diabetes patients, as well as the response of interest, a\nquantitative measure of disease progression one year after baseline.\n\n**Data Set Characteristics:**\n\n  :Number of Instances: 442\n\n  :Number of Attributes: First 10 columns are numeric predictive values\n\n  :Target: Column 11 is a quantitative measure of disease progression one year after baseline\n\n  :Attribute Information:\n      - age     age in years\n      - sex\n      - bmi     body mass index\n      - bp      average blood pressure\n      - s1      tc, total serum cholesterol\n      - s2      ldl, low-density lipoproteins\n      - s3      hdl, high-density lipoproteins\n      - s4      tch, total cholesterol / HDL\n      - s5      ltg, possibly log of serum triglycerides level\n      - s6      glu, blood sugar level\n\nNote: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).\n\nSource URL:\nhttps://www4.stat.ncsu.edu/~boos/var.select/diabetes.html\n\nFor more information see:\nBradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.\n(https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)\n'

# %%
data = pd.DataFrame(dataset['data'],columns = ['age','sex','bmi','bp','s1','s2','s3','s4','s5','s6'])
data.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
X= data
y = dataset['target']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state=40)

# %%
X_train.head()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 161 -0.045472  0.050680  0.063852  0.070072  0.133274  0.131461 -0.039719
# 27  -0.023677 -0.044642  0.059541 -0.040099 -0.042848 -0.043589  0.011824
# 149 -0.049105  0.050680 -0.005128 -0.046985 -0.020832 -0.020416 -0.069172
# 188  0.005383 -0.044642 -0.002973  0.049415  0.074108  0.070710  0.044958
# 246  0.041708 -0.044642 -0.032073 -0.061892  0.079612  0.050982  0.056003
#
#            s4        s5        s6
# 161  0.108111  0.075741  0.085907
# 27  -0.039493 -0.015999  0.040343
# 149  0.071210  0.061238 -0.038357
# 188 -0.002592 -0.001496 -0.009362
# 246 -0.009972  0.045067 -0.059067

# %%
X_train.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.141301  0.234150  0.332892  0.285592  0.260704 -0.095826
# sex  0.141301  1.000000  0.103081  0.217275  0.002696  0.124169 -0.383618
# bmi  0.234150  0.103081  1.000000  0.484194  0.263851  0.281320 -0.331715
# bp   0.332892  0.217275  0.484194  1.000000  0.272348  0.216771 -0.171849
# s1   0.285592  0.002696  0.263851  0.272348  1.000000  0.898255  0.099838
# s2   0.260704  0.124169  0.281320  0.216771  0.898255  1.000000 -0.174089
# s3  -0.095826 -0.383618 -0.331715 -0.171849  0.099838 -0.174089  1.000000
# s4   0.241654  0.336603  0.391250  0.275347  0.514499  0.670592 -0.732113
# s5   0.282784  0.128841  0.426544  0.420387  0.507038  0.317096 -0.344825
# s6   0.323534  0.263595  0.373092  0.478257  0.319552  0.305478 -0.249945
#
#            s4        s5        s6
# age  0.241654  0.282784  0.323534
# sex  0.336603  0.128841  0.263595
# bmi  0.391250  0.426544  0.373092
# bp   0.275347  0.420387  0.478257
# s1   0.514499  0.507038  0.319552
# s2   0.670592  0.317096  0.305478
# s3  -0.732113 -0.344825 -0.249945
# s4   1.000000  0.562816  0.390806
# s5   0.562816  1.000000  0.424126
# s6   0.390806  0.424126  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,10))
sns.heatmap(X_train.corr(),annot=True)
# %matplotlib inline

# %%
## Decesion Tree 
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

regressor = DecisionTreeRegressor()
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ### Hyperparameter Tuning

# %%
param={
    'criterion':['squared_error','friedman_mse','absolute_error'],
    'splitter':['best','random'],
    'max_depth':[1,2,3,4,5,10,15,20,25],
    'max_features':['auto','sqrt','log2']
}

# %%
regressor = DecisionTreeRegressor()
grid=GridSearchCV(regressor,param_grid=param,cv=5,scoring='neg_mean_squared_error')

# %%
import warnings
warnings.filterwarnings('ignore')
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
grid.best_params_
# Out:
# {'criterion': 'absolute_error',
#  'max_depth': 5,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
## predictions
y_pred=grid.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.07576641195625888
# 57.578947368421055
# 5698.586466165413

# %%
selectedmodel=DecisionTreeRegressor(criterion='friedman_mse',max_depth=4,max_features='log2',splitter='random')

# %%
selectedmodel.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=4,
#                       max_features='log2', splitter='random')

# %%
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(selectedmodel,filled=True)
# Out:
# [Text(0.5267857142857143, 0.9, 'x[5] <= 0.019\nfriedman_mse = 5760.123\nsamples = 309\nvalue = 147.602'),
#  Text(0.2857142857142857, 0.7, 'x[2] <= 0.018\nfriedman_mse = 5985.726\nsamples = 211\nvalue = 137.701'),
#  Text(0.14285714285714285, 0.5, 'x[2] <= -0.08\nfriedman_mse = 3529.529\nsamples = 158\nvalue = 112.051'),
#  Text(0.07142857142857142, 0.3, 'x[9] <= -0.088\nfriedman_mse = 336.917\nsamples = 6\nvalue = 84.5'),
#  Text(0.03571428571428571, 0.1, 'friedman_mse = 110.25\nsamples = 2\nvalue = 61.5'),
#  Text(0.10714285714285714, 0.1, 'friedman_mse = 53.5\nsamples = 4\nvalue = 96.0'),
#  Text(0.21428571428571427, 0.3, 'x[0] <= 0.063\nfriedman_mse = 3624.409\nsamples = 152\nvalue = 113.138'),
#  Text(0.17857142857142858, 0.1, 'friedman_mse = 3403.138\nsamples = 145\nvalue = 110.593'),
#  Text(0.25, 0.1, 'friedman_mse = 5294.408\nsamples = 7\nvalue = 165.857'),
#  Text(0.42857142857142855, 0.5, 'x[0] <= -0.019\nfriedman_mse = 5499.084\nsamples = 53\nvalue = 214.17'),
#  Text(0.35714285714285715, 0.3, 'x[8] <= 0.04\nfriedman_mse = 4363.496\nsamples = 19\nvalue = 174.632'),
#  Text(0.32142857142857145, 0.1, 'friedman_mse = 3984.959\nsamples = 14\nvalue = 161.429'),
#  Text(0.39285714285714285, 0.1, 'friedman_mse = 3568.64\nsamples = 5\nvalue = 211.6'),
#  Text(0.5, 0.3, 'x[3] <= -0.038\nfriedman_mse = 4771.901\nsamples = 34\nvalue = 236.265'),
#  Text(0.4642857142857143, 0.1, 'friedman_mse = 5246.889\nsamples = 3\nvalue = 173.667'),
#  Text(0.5357142857142857, 0.1, 'friedman_mse = 4310.025\nsamples = 31\nvalue = 242.323'),
#  Text(0.7678571428571429, 0.7, 'x[8] <= -0.027\nfriedman_mse = 4608.953\nsamples = 98\nvalue = 168.918'),
#  Text(0.6785714285714286, 0.5, 'x[5] <= 0.098\nfriedman_mse = 2119.456\nsamples = 13\nvalue = 119.923'),
#  Text(0.6428571428571429, 0.3, 'x[0] <= -0.056\nfriedman_mse = 2003.556\nsamples = 12\nvalue = 124.667'),
#  Text(0.6071428571428571, 0.1, 'friedman_mse = 2704.0\nsamples = 2\nvalue = 148.0'),
#  Text(0.6785714285714286, 0.1, 'friedman_mse = 1732.8\nsamples = 10\nvalue = 120.0'),
#  Text(0.7142857142857143, 0.3, 'friedman_mse = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.8571428571428571, 0.5, 'x[3] <= -0.023\nfriedman_mse = 4566.407\nsamples = 85\nvalue = 176.412'),
#  Text(0.7857142857142857, 0.3, 'x[2] <= 0.076\nfriedman_mse = 3983.442\nsamples = 21\nvalue = 139.286'),
#  Text(0.75, 0.1, 'friedman_mse = 3157.81\nsamples = 20\nvalue = 132.3'),
#  Text(0.8214285714285714, 0.1, 'friedman_mse = 0.0\nsamples = 1\nvalue = 279.0'),
#  Text(0.9285714285714286, 0.3, 'x[2] <= 0.11\nfriedman_mse = 4157.022\nsamples = 64\nvalue = 188.594'),
#  Text(0.8928571428571429, 0.1, 'friedman_mse = 4185.223\nsamples = 63\nvalue = 187.825'),
#  Text(0.9642857142857143, 0.1, 'friedman_mse = 0.0\nsamples = 1\nvalue = 237.0')]
