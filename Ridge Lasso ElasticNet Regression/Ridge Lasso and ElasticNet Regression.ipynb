# %% [markdown]
# ### Important Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset=pd.read_csv('/Users/bibhasgiri/Downloads/Ridge Lassso Elastic Regression Practicals/Algerian_forest_fires_dataset_UPDATE.csv',header=1)

# %%
dataset.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %% [markdown]
# #### Basic Information of Data

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %% [markdown]
# #### Data Cleaning

# %%
dataset.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
# Now we are assigning region for two area-- 
#'Bejaia Region Dataset' will be zero and Sidi-Bei Abbes Region Dataset' will be 1

dataset.loc[:122,'Region']=0
dataset.loc[122:,'Region']=1
dataset
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire        0.0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.0+ KB

# %%
dataset[['Region']]=dataset[['Region']].astype(int)

# %%
# Remove Null Values

dataset = dataset.dropna().reset_index(drop=True)
dataset.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
dataset.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
# Remove unnessary column name in 122nd row

dataset.iloc[[122]]
dataset=dataset.drop(122).reset_index(drop=True)

# %%
dataset.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122  01    06  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
dataset.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
dataset.columns = dataset.columns.str.strip()
dataset.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %% [markdown]
# #### Change Data type

# %%
dataset[['day', 'month', 'year', 'Temperature', 'RH','Ws']]=dataset[['day', 'month', 'year', 'Temperature', 'RH','Ws']].astype(int)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(7), object(8)
# memory usage: 28.6+ KB

# %%
objects = [features for features in dataset.columns if dataset[features].dtype=='O']

# %%
for i in objects:
    if i != 'Classes':
        dataset[i] = dataset[i].astype(float)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.6+ KB

# %%
dataset.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %%
dataset.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df_copy = dataset.drop(['day','month','year'],axis=1)
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df_copy['Classes'].value_counts()
# Out:
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
## Encoding categorical attrribute 
df_copy['Classes'] = np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df_copy['Classes'].value_counts()
# Out:
# 1    137
# 0    106
# Name: Classes, dtype: int64

# %%
plt.style.use('seaborn')
df_copy.hist(bins=50,figsize=(20,15))
plt.show()
# Out:
# /var/folders/gf/mkjgt1c51_s53fts0ybhhp8m0000gn/T/ipykernel_28740/1062445420.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# Percentage of classes

percentage=df_copy['Classes'].value_counts(normalize=True)*100

# %%
# Pie chart of classes
classlabels = ["Fire","Not Fire"]
plt.figure(figsize=(5,5))
plt.pie(percentage,labels=classlabels,autopct='%1.1f%%')
plt.title('Pie chart of classes')
plt.show()

# %%
# Correlation between independent atrributes
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
sns.heatmap(df_copy.corr())
# Out:
# <Axes: >

# %%
# Box plot to check outlier

sns.boxplot(df_copy['FWI'])
# Out:
# <Axes: >

# %%
dataset_1 = dataset.copy()
dataset_1['Classes'] = np.where(dataset_1['Classes'].str.contains('not fire'),'Not Fire','Fire')

# %%
## Monthly fire analysis

dftemp = df_copy.loc[df_copy['Region']==1]
plt.subplots(figsize=(8,4))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=dataset_1)
plt.ylabel("Number of Fires",weight='bold')
plt.xlabel("Months",weight='bold')
plt.title('Fire analysis of two regions(Bejaia Region and Sidi-Bei Abbes Region)')
# Out:
# Text(0.5, 1.0, 'Fire analysis of two regions(Bejaia Region and Sidi-Bei Abbes Region)')

# %%
# Using Clean data here
df=pd.read_csv('/Users/bibhasgiri/Downloads/Ridge Lassso Elastic Regression Practicals/Algerian_forest_fires_cleaned_dataset.csv')

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.drop(['day', 'month', 'year'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df['Classes'].value_counts()
# Out:
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
#Encoding

df['Classes'] = np.where(df['Classes'].str.contains("not fire"),0,1)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df['Classes'].value_counts()
# Out:
# 1    137
# 0    106
# Name: Classes, dtype: int64

# %%
## Indipendent and Dependent Features
X=df.drop('FWI',axis=1)
y=df['FWI']

# %%
X.head(2)
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC   DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4  7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1  7.6  1.0  3.9        0       0

# %%
y.head(2)
# Out:
# 0    0.5
# 1    0.4
# Name: FWI, dtype: float64

# %%
# train & test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 11), (61, 11))

# %%
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# DC              0.390684 -0.236078  0.096576 -0.302341  0.524101  0.868647
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  0.983175
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  0.212582
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %%
## Check multicoliniarity
plt.figure(figsize=(10,5))
corr=X_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
def correlation(dataset,threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
## Check columns name which are more than threshold value
correlation(X_train,0.85)
# Out:
# {'BUI', 'DC'}

# %%
corr_features = correlation(X_train,0.85)

# %%
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 9), (61, 9))

# %% [markdown]
# #### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.84284248,  0.78307967,  1.29972026, ..., -0.62963326,
#         -1.10431526, -0.98907071],
#        [-0.30175842,  0.64950844, -0.59874754, ..., -0.93058524,
#         -1.10431526,  1.01105006],
#        [ 2.13311985, -2.08870172, -0.21905398, ...,  2.7271388 ,
#          0.90553851,  1.01105006],
#        ...,
#        [-1.9250106 ,  0.9166509 ,  0.54033314, ..., -1.06948615,
#         -1.10431526, -0.98907071],
#        [ 0.50986767, -0.21870454,  0.16063958, ...,  0.5973248 ,
#          0.90553851,  1.01105006],
#        [-0.57230045,  0.98343651,  2.05910739, ..., -0.86113478,
#         -1.10431526, -0.98907071]])

# %%
## Box plot to check out liar and effect of standardzation
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(data=X_train)
plt.title('X train before scaling')
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title('X train after scaling')
# Out:
# /var/folders/gf/mkjgt1c51_s53fts0ybhhp8m0000gn/T/ipykernel_28740/2441361563.py:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)
# Text(0.5, 1.0, 'X train after scaling')

# %% [markdown]
# #### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
linreg = LinearRegression()
linreg.fit(X_train_scaled,y_train)
y_pred = linreg.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"R Square: {score}")
# Out:
# Mean Absolute Error: 0.5468236465249977
# R Square: 0.9847657384266951

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# #### Lasso Rigression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lasso = Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred = lasso.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"R Square: {score}")
# Out:
# Mean Absolute Error: 1.133175994914409
# R Square: 0.9492020263112388

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# #### Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge = Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred = ridge.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"R Square: {score}")
# Out:
# Mean Absolute Error: 0.5642305340105692
# R Square: 0.9842993364555513

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# #### Elasticnet Regression

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ElasticNet = ElasticNet()
ElasticNet.fit(X_train_scaled,y_train)
y_pred = ElasticNet.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"R Square: {score}")
# Out:
# Mean Absolute Error: 1.8822353634896005
# R Square: 0.8753460589519703

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# #### Cross Validation Lasso

# %%
from sklearn.linear_model import LassoCV
lassocv = LassoCV(cv=5)
lassocv.fit(X_train_scaled,y_train)
# Out:
# LassoCV(cv=5)

# %%
lassocv.predict(X_test_scaled)
# Out:
# array([ 8.17490595,  7.68312478, -0.25676525,  4.72643402,  6.78715772,
#         1.77624325,  2.23148094,  7.64057821,  1.99176323,  3.39941035,
#         0.62808928,  9.95945488,  9.36168319, 16.98503659, 18.28488762,
#         1.61644108,  1.62751276, -0.6415713 ,  7.28510526,  3.10926518,
#         1.95541903,  0.18069335,  6.47563129,  0.14318503, 20.99597009,
#         5.11755206,  5.86208849,  9.75914403, -0.77037467,  9.91838577,
#         6.72277075, -0.31776007, 10.31109643, 14.4365551 ,  1.71022677,
#         0.83439752,  2.03414915,  5.97488529, -0.6263644 , -0.56200288,
#         6.47253729,  2.07971408,  8.46741557, -0.8464481 , 15.40443856,
#         8.32941189,  8.48782486,  1.44030355, 13.02752812,  1.20911545,
#        29.08623849,  5.49737681, 17.15937199, 19.28890096, 13.71102991,
#        16.05355549,  0.99056448,  9.0873725 ,  3.84455993, 14.43991192,
#         5.23034139])

# %%
lassocv.alpha_
# Out:
# 0.05725391318234405

# %%
lassocv.alphas_
# Out:
# array([7.05853002e+00, 6.58280872e+00, 6.13914944e+00, 5.72539132e+00,
#        5.33951911e+00, 4.97965339e+00, 4.64404142e+00, 4.33104857e+00,
#        4.03915039e+00, 3.76692517e+00, 3.51304702e+00, 3.27627941e+00,
#        3.05546914e+00, 2.84954075e+00, 2.65749124e+00, 2.47838523e+00,
#        2.31135036e+00, 2.15557308e+00, 2.01029467e+00, 1.87480753e+00,
#        1.74845178e+00, 1.63061198e+00, 1.52071419e+00, 1.41822315e+00,
#        1.32263965e+00, 1.23349817e+00, 1.15036452e+00, 1.07283380e+00,
#        1.00052839e+00, 9.33096128e-01, 8.70208572e-01, 8.11559427e-01,
#        7.56863037e-01, 7.05853002e-01, 6.58280872e-01, 6.13914944e-01,
#        5.72539132e-01, 5.33951911e-01, 4.97965339e-01, 4.64404142e-01,
#        4.33104857e-01, 4.03915039e-01, 3.76692517e-01, 3.51304702e-01,
#        3.27627941e-01, 3.05546914e-01, 2.84954075e-01, 2.65749124e-01,
#        2.47838523e-01, 2.31135036e-01, 2.15557308e-01, 2.01029467e-01,
# ...

# %%
lassocv.mse_path_
# Out:
# array([[53.64536329, 65.39074075, 54.89628985, 77.90299066, 39.38236846],
#        [46.99139716, 59.81506814, 49.29840831, 75.6645852 , 35.31758355],
#        [41.14908917, 53.9178721 , 42.49594889, 68.35708298, 31.76996123],
#        [36.05788169, 48.41773965, 36.66879347, 61.92819453, 28.67296816],
#        [31.62067285, 42.76466229, 31.68391904, 56.26841266, 24.93183295],
#        [27.75285367, 37.81922812, 27.42599138, 51.28216115, 21.56888645],
#        [24.3807738 , 33.49107651, 23.7950306 , 45.25481907, 18.66094162],
#        [21.44052804, 29.70161639, 20.70460191, 39.90418045, 16.14837778],
#        [18.876308  , 26.38208059, 18.07969934, 35.23429953, 13.97821475],
#        [16.63960395, 23.47341883, 15.85530749, 31.15712074, 12.10483403],
#        [14.68819307, 20.92329068, 13.97555108, 27.59649208, 10.48862803],
#        [12.98525144, 18.68636627, 12.39173305, 24.48611006,  9.09521221],
#        [11.49893734, 16.72312788, 11.06186319, 21.7677198 ,  7.89445038],
# ...

# %%
y_pred = lassocv.predict(X_test_scaled)
plt.scatter(y_test,y_pred)

# %%
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"R Square: {score}")
# Out:
# Mean Absolute Error: 1.133175994914409
# R Square: 0.9492020263112388

# %%
from sklearn.linear_model import RidgeCV
ridgecv = RidgeCV(cv=5)
ridgecv.fit(X_train_scaled,y_train)
y_pred = ridgecv.predict(X_test_scaled)

plt.scatter(y_test,y_pred)

mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"R Square: {score}")
# Out:
# Mean Absolute Error: 0.5642305340105692
# R Square: 0.9842993364555513

# %%
from sklearn.linear_model import ElasticNetCV
elasticnetcv = ElasticNetCV(cv=5)
elasticnetcv.fit(X_train_scaled,y_train)
y_pred = elasticnetcv.predict(X_test_scaled)
plt.scatter(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print(f"Mean Absolute Error: {mae}")
print(f"R Square: {score}")
# Out:
# Mean Absolute Error: 0.6575946731430898
# R Square: 0.9814217587854941
